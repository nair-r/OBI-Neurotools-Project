# %% [markdown]
# # Running mriqc on BIDS converted data

# %% [markdown]
# **Runs the mriqc docker image**
#
# **Input**: Validated BIDS data
#
# **Output**: Reports and figures showing quality control metrics generated by mriqc (will be visualised in cell 5)

# %% [markdown]
# Preparation:
#
# * Make sure docker is installed
# * Start docker

# %% [markdown]
# Check that the docker installation works

# %%
# !docker run poldracklab/mriqc:latest --version
# Out:
# mriqc v0.9.8-1

# %% [markdown]
# Run the mriqc docker image.
#
# *Note: The paths here have to be changed to wherever we will have the data.*

# %%
# !docker run --rm -v c:/Users/kwie508/OBI-Neurotools-Project/data:/data:ro -v c:/Users/kwie508/OBI-Neurotools-Project/mriqc:/out poldracklab/mriqc:latest /data /out participant
# Out:
# 2017-09-22 08:02:41,719 interface:WARNING AFNI is outdated, detected version Debian-16.2.07~dfsg.1-5~nd16.04+1 and AFNI_17.2.16 is available.
# 2017-09-22 08:02:42,999 interface:WARNING AFNI is outdated, detected version Debian-16.2.07~dfsg.1-5~nd16.04+1 and AFNI_17.2.16 is available.
# 2017-09-22 08:02:45,972 interface:WARNING AFNI is outdated, detected version Debian-16.2.07~dfsg.1-5~nd16.04+1 and AFNI_17.2.16 is available.
# 2017-09-22 08:02:47,209 interface:WARNING AFNI is outdated, detected version Debian-16.2.07~dfsg.1-5~nd16.04+1 and AFNI_17.2.16 is available.
# 2017-09-22 08:02:47,376 mriqc.cli:WARNING Anonymized quality metrics will be submitted to MRIQC's metrics repository. Use --no-sub to disable submission.
# 2017-09-22 08:13:09,085 niworkflows:INFO Estimating initial transform using AffineInitializer
# 2017-09-22 08:16:08,564 niworkflows:INFO Loading settings from file /usr/local/miniconda/lib/python3.6/site-packages/niworkflows/data/t1-mni_registration_fast_000.json.
# ...
